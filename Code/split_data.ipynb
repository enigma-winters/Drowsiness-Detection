# %%
import os
from PIL import Image
num = []
for i in range(0,10):
    s = '0' + str(i)
    num.append(s)
for i in range(10,38):
    s = str(i)
    num.append(s)
num
p = '/s00'
path = '/home/chirag/tfwork/mrlEyes_2018_01'
closed = '/close'
opened = '/open'
for n in num[1:]:
    print('subject : ' + n + '\n')
    test = [file for file in os.listdir(path + p + n)]
    print(len(test))
    for img in test:
        if(img[16] == '0'):
            os.rename(path + p + n + '/' + img, path + closed + '/' + img)
    test = [file for file in os.listdir(path + p + n)]
    print(len(test))
    for img in test:
        if(img[16] == '1'):
            try:
                os.rename(path + p + n+'/' + img, path + opened + '/' + img)
            except: 
                pass
    test = [file for file in os.listdir(path + p + n)]
    print(len(test))
# Out:
# subject : 01
#
# 3242
# 1401
# 0
# subject : 02
#
# 1114
# 107
# 0
# subject : 03
#
# 679
# 120
# 0
# subject : 04
#
# 1069
# 0
# 0
# subject : 05
#
# 736
# 28
# 0
# subject : 06
#
# 1012
# 1
# 0
# subject : 07
#
# 624
# 11
# 0
# subject : 08
#
# 832
# 0
# 0
# subject : 09
#
# 387
# 24
# 0
# subject : 10
#
# 399
# 68
# 0
# subject : 11
#
# 1648
# 140
# 0
# subject : 12
#
# 8728
# 4230
# 0
# subject : 13
#
# 3605
# 630
# 0
# subject : 14
#
# 8884
# 5116
# 0
# subject : 15
#
# 1132
# 348
# 0
# subject : 16
#
# 1889
# 173
# 0
# subject : 17
#
# 1648
# 329
# 0
# subject : 18
#
# 4410
# 721
# 0
# subject : 19
#
# 6175
# 3268
# 0
# subject : 20
#
# 704
# 679
# 0
# subject : 21
#
# 987
# 852
# 0
# subject : 22
#
# 382
# 256
# 0
# subject : 23
#
# 522
# 467
# 0
# subject : 24
#
# 752
# 547
# 0
# subject : 25
#
# 1502
# 1365
# 0
# subject : 26
#
# 1246
# 837
# 0
# subject : 27
#
# 665
# 573
# 0
# subject : 28
#
# 736
# 723
# 0
# subject : 29
#
# 1393
# 1216
# 0
# subject : 30
#
# 1384
# 1053
# ...
